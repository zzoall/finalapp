# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s.pt")  # load a pretrained model (recommended for training)

# %%
# Use the model
results = model.train(data="data.yaml", epochs=30, batch=4, patience=50, device=0,workers=0 , imgsz=640)  # train the model
results = model.val()  # evaluate model performance on the validation set
#results = model(r"C:\Users\Administrator\Documents\dev\ai-bootcamp\Project\final\face\train\images\wider_0.jpg")  # predict on an image
# Out:
# Ultralytics YOLOv8.0.53  Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.53  Python-3.9.16 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
#
# PyTorch: starting from runs\detect\train41\weights\best.pt with input shape (4, 3, 640, 640) BCHW and output shape(s) (4, 5, 8400) (21.4 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# ...
#      --------------------------------------- 12.2/12.2 MB 73.0 MB/s eta 0:00:00
# ...
#   Using cached protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: export success  5.4s, saved as runs\detect\train41\weights\best.onnx (42.6 MB)
#
# Export complete (5.7s)
# Results saved to C:\Users\Administrator\Documents\dev\ai-bootcamp\Project\final\runs\detect\train41\weights
# Predict:         yolo predict task=detect model=runs\detect\train41\weights\best.onnx imgsz=640
# ...
